# %% [markdown]
# Education Data Analytics for ETL Project
#
# -Focus on years 2001-2016

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
education_file = "../Data/education_data/states_all.csv"
education_df = pd.read_csv(education_file)
education_df.head(100)
# Out:
#                   PRIMARY_KEY                 STATE  YEAR     ENROLL  \
# 0                1992_ALABAMA               ALABAMA  1992        NaN
# 1                 1992_ALASKA                ALASKA  1992        NaN
# 2                1992_ARIZONA               ARIZONA  1992        NaN
# 3               1992_ARKANSAS              ARKANSAS  1992        NaN
# 4             1992_CALIFORNIA            CALIFORNIA  1992        NaN
# 5               1992_COLORADO              COLORADO  1992        NaN
# 6            1992_CONNECTICUT           CONNECTICUT  1992        NaN
# 7               1992_DELAWARE              DELAWARE  1992        NaN
# 8   1992_DISTRICT_OF_COLUMBIA  DISTRICT_OF_COLUMBIA  1992        NaN
# 9                1992_FLORIDA               FLORIDA  1992        NaN
# 10               1992_GEORGIA               GEORGIA  1992        NaN
# 11                1992_HAWAII                HAWAII  1992        NaN
# 12                 1992_IDAHO                 IDAHO  1992        NaN
# ...

# %%
education_df.columns
# Out:
# Index(['PRIMARY_KEY', 'STATE', 'YEAR', 'ENROLL', 'TOTAL_REVENUE',
#        'FEDERAL_REVENUE', 'STATE_REVENUE', 'LOCAL_REVENUE',
#        'TOTAL_EXPENDITURE', 'INSTRUCTION_EXPENDITURE',
#        'SUPPORT_SERVICES_EXPENDITURE', 'OTHER_EXPENDITURE',
#        'CAPITAL_OUTLAY_EXPENDITURE', 'GRADES_PK_G', 'GRADES_KG_G',
#        'GRADES_4_G', 'GRADES_8_G', 'GRADES_12_G', 'GRADES_1_8_G',
#        'GRADES_9_12_G', 'GRADES_ALL_G', 'AVG_MATH_4_SCORE', 'AVG_MATH_8_SCORE',
#        'AVG_READING_4_SCORE', 'AVG_READING_8_SCORE'],
#       dtype='object')

# %% [markdown]
# Academic Achievement -  National Assessment of Educational Progress (NAEP)
#
# A breakdown of student performance as assessed by the corresponding exams (math and reading, grades 4 and 8).
#
# AVG_MATH_4_SCORE: The state's average score for fourth graders taking the NAEP math exam.
#
# AVG_MATH_8_SCORE: The state's average score for eight graders taking the NAEP math exam.
#
# AVG_READING_4_SCORE: The state's average score for fourth graders taking the NAEP reading exam.
#
# AVG_READING_8_SCORE: The state's average score for eighth graders taking the NAEP reading exam.

# %%
# Create a filtered dataframe from specific columns

education_cols = ['STATE', 'YEAR', 'TOTAL_EXPENDITURE', 'INSTRUCTION_EXPENDITURE', 'GRADES_4_G', 'GRADES_8_G', 'GRADES_ALL_G', 'AVG_MATH_4_SCORE', 'AVG_MATH_8_SCORE', 'AVG_READING_4_SCORE', 'AVG_READING_8_SCORE']
education_transformed = education_df[education_cols].copy()

education_transformed.head()
# Out:
#         STATE  YEAR  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  GRADES_4_G  \
# 0     ALABAMA  1992          2653798.0                1481703.0     57948.0
# 1      ALASKA  1992           972488.0                 498362.0      9748.0
# 2     ARIZONA  1992          3401580.0                1435908.0     55433.0
# 3    ARKANSAS  1992          1743022.0                 964323.0     34632.0
# 4  CALIFORNIA  1992         27138832.0               14358922.0    418418.0
#
#    GRADES_8_G  GRADES_ALL_G  AVG_MATH_4_SCORE  AVG_MATH_8_SCORE  \
# 0     58025.0      676174.0        208.327876        252.187522
# 1      8789.0      112335.0               NaN               NaN
# 2     49081.0      614881.0        215.253932        265.366278
# 3     36011.0      405259.0        210.206028        256.312090
# 4    363296.0     4717112.0        208.398961        260.892247
#
#    AVG_READING_4_SCORE  AVG_READING_8_SCORE
# 0           207.963517                  NaN
# ...

# %%
# Rename the column headers
education_transformed = education_transformed.rename(columns={"GRADES_4_G": "4TH_ENROLLED",
                                                          "GRADES_8_G": "8TH_ENROLLED",
                                                          "GRADES_ALL_G": "TOTAL_ENROLLMENT",
                                                            "AVG_MATH_4_SCORE": "4_AVG_MATH_SCORE",
                                                             "AVG_MATH_8_SCORE": "8_AVG_MATH_SCORE",
                                                             "AVG_READING_4_SCORE": "4_AVG_RDG_SCORE",
                                                             "AVG_READING_8_SCORE": "8_AVG_RDG_SCORE"})
education_transformed.head()
# Out:
#         STATE  YEAR  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  4TH_ENROLLED  \
# 0     ALABAMA  1992          2653798.0                1481703.0       57948.0
# 1      ALASKA  1992           972488.0                 498362.0        9748.0
# 2     ARIZONA  1992          3401580.0                1435908.0       55433.0
# 3    ARKANSAS  1992          1743022.0                 964323.0       34632.0
# 4  CALIFORNIA  1992         27138832.0               14358922.0      418418.0
#
#    8TH_ENROLLED  TOTAL_ENROLLMENT  4_AVG_MATH_SCORE  8_AVG_MATH_SCORE  \
# 0       58025.0          676174.0        208.327876        252.187522
# 1        8789.0          112335.0               NaN               NaN
# 2       49081.0          614881.0        215.253932        265.366278
# 3       36011.0          405259.0        210.206028        256.312090
# 4      363296.0         4717112.0        208.398961        260.892247
#
#    4_AVG_RDG_SCORE  8_AVG_RDG_SCORE
# 0       207.963517              NaN
# ...

# %%
# Filter by year - We want 2001-2016

education_year = education_transformed[(education_transformed['YEAR'] > 2000) & (education_transformed['YEAR'] < 2017)]

#df[(df['Score'] > 70) & (df['Score'] < 85)]
#education_years = education_year[education_year['YEAR'] < 2017]

education_year.head()
# Out:
#           STATE  YEAR  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 459     ALABAMA  2001          5086045.0                2656393.0
# 460      ALASKA  2001          1402839.0                 701053.0
# 461     ARIZONA  2001          5858385.0                2538936.0
# 462    ARKANSAS  2001          2951677.0                1616883.0
# 463  CALIFORNIA  2001         52082540.0               26641811.0
#
#      4TH_ENROLLED  8TH_ENROLLED  TOTAL_ENROLLMENT  4_AVG_MATH_SCORE  \
# 459       58929.0       56591.0          683042.0               NaN
# 460       10718.0       10702.0          124254.0               NaN
# 461       74270.0       69643.0          841750.0               NaN
# 462       35216.0       35372.0          413278.0               NaN
# 463      485301.0      461133.0         5717489.0               NaN
#
#      8_AVG_MATH_SCORE  4_AVG_RDG_SCORE  8_AVG_RDG_SCORE
# 459               NaN              NaN              NaN
# ...

# %%
# Drop rows with NaN values - the only rows in the dataset with NaN values are not U.S. States

# %%
# Clean the data by dropping duplicates and setting the index
# premise_transformed.set_index("id", inplace=True)

# premise_transformed.head()
